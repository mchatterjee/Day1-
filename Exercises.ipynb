# %%
6+4
# Out:
# 10

# %%
import pandas as pd
pd.set_option("display.max_rows",1000)    # or pd.options.display.max_rows=1000
pd.set_option("display.max_columns",20)   # or pd.options.display.max_columns=20 
pd.set_option('precision',7)
pd.set_option('large_repr', 'truncate')

# %%
import pandas as pd
data = pd.DataFrame({'group': ['a', 'a', 'a', 'b','b', 'b', 'c', 'c','c'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#   group  ounces
# 0     a     4.0
# 1     a     3.0
# 2     a    12.0
# 3     b     6.0
# 4     b     7.5
# 5     b     8.0
# 6     c     3.0
# 7     c     5.0
# 8     c     6.0

# %%
data.describe()
# Out:
#            ounces
# count   9.0000000
# mean    6.0555556
# std     2.8553069
# min     3.0000000
# 25%     4.0000000
# 50%     6.0000000
# 75%     7.5000000
# max    12.0000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
# group     9 non-null object
# ounces    9 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 216.0+ bytes

# %%
import pandas as pd
data = pd.DataFrame({'k1': ['one'] * 3 + ['two'] * 4, 'k2': [3, 2, 1, 3, 3, 4, 4]})

# %%
data
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two   4

# %%
data.sort_values(by='k2')
data
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 4  two   3
# 5  two   4
# 6  two   4

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 5  two   4

# %%
data.drop_duplicates(subset='k1')
# Out:
#     k1  k2
# 0  one   3
# 3  two   3

# %%
import pandas as pd
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'Pastrami','corned beef', 'Bacon', 'pastrami', 'honey ham','nova lox'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'honey ham': 'pig',
'nova lox': 'salmon'
}

def meat2animal(series):
    if series["food"]=='bacon':
        return 'pig'
    elif series["food"]=='pulled pork':
        return 'pig'
    elif series["food"]=='pastrami':
        return 'cow'
    elif series["food"]=='corned beef':
        return 'cow'
    elif series["food"]=='honey ham':
        return 'pig'
    else:
        return 'salmon'

# %%
data['animal'] = data['food'].map(str.lower).map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
data['animal2'] = data.apply(meat2animal,axis='1)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-287ccd2cf3f2> in <module>()
# ----> 1 data['animal2'] = data.apply(meat2animal,axis='1')
#       2 data
#       3
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4033         applied : Series or DataFrame
#    4034         """
# -> 4035         axis = self._get_axis_number(axis)
#    4036         if kwds or args and not isinstance(func, np.ufunc):
#    4037
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_axis_number(self, axis)
#     316                 pass
#     317         raise ValueError('No axis named {0} for object type {1}'
# --> 318                          .format(axis, type(self)))
#     319
#     320     def _get_axis_name(self, axis):
#
# ...

# %%
data['animal2'] = data.apply(meat2animal,axis=1)
data
# Out:
#           food  ounces  animal animal2
# 0        bacon     4.0     pig     pig
# 1  pulled pork     3.0     pig     pig
# 2        bacon    12.0     pig     pig
# 3     Pastrami     6.0     cow  salmon
# 4  corned beef     7.5     cow     cow
# 5        Bacon     8.0     pig  salmon
# 6     pastrami     3.0     cow     cow
# 7    honey ham     5.0     pig     pig
# 8     nova lox     6.0  salmon  salmon

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'data1' : np.random.randn(6),
                   'data2' : np.random.randn(6)})

df.assign(ratio = df['data1'] / df['data2'])
# Out:
#        data1      data2      ratio
# 0  2.2135905  1.3295688  1.6648935
# 1  1.2839958 -0.4239931 -3.0283413
# 2 -0.1219607  1.6698721 -0.0730359
# 3 -1.7366947  0.8184280 -2.1219884
# 4 -1.7853773  0.7999722 -2.2317992
# 5  0.0480153 -0.0314728 -1.5256133

# %%
data.drop('animal2', axis='columns', inplace=True)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %%
import pandas as pd
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan, inplace=True)
data
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data = pd.DataFrame

# %%
data
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
data = pd.DataFrame(np.arange(12).reshape((3, 4)),index=['Ohio', 'Colorado', 'New York'],columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
data.index.map(str.upper)
# Out:
# array(['OHIO', 'COLORADO', 'NEW YORK'], dtype=object)

# %%
data.index = data.index.map(str.upper)
data
# Out:
#           one  two  three  four
# OHIO        0    1      2     3
# COLORADO    4    5      6     7
# NEW YORK    8    9     10    11

# %%
data.rename(index=str.title, columns=str.upper, inplace=True)
data
# Out:
#           ONE  TWO  THREE  FOUR
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ml-1m\movies.dat',delimeter ='::')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2132066e6878> in <module>()
# ----> 1 df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ml-1m\movies.dat',delimeter ='::')
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2569c44faf66> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ml-1m\movies.dat',delimeter ='::')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2132066e6878> in <module>()
# ----> 1 df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ml-1m\movies.dat',delimeter ='::')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ml-1m\movies.dat',delimeter ='::')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-7a23a5726fa0> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ml-1m\movies.dat',delimeter ='::')
#
# TypeError: parser_f() got an unexpected keyword argument 'delimeter'

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2569c44faf66> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\movies.dat',delimiter ='::')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-361f0a06322a> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\movies.dat',delimeter ='::')
#
# TypeError: parser_f() got an unexpected keyword argument 'delimeter'

# %%
import pandas as pd
df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\m1-1m\movies.dat',delimiter ='::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
import pandas as pd
df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\m1-1m\movies.dat',delimiter ='::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-3c62eb8756dd> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\m1-1m\movies.dat',delimiter ='::')
#
# ...

# %%
import pandas as pd
df = pd.read_csv('C:\mita\Data Science workshop\ml-1m\movies.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
df.head()
# Out:
#    1                    Toy Story (1995)   Animation|Children's|Comedy
# 0  2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 1  3             Grumpier Old Men (1995)                Comedy|Romance
# 2  4            Waiting to Exhale (1995)                  Comedy|Drama
# 3  5  Father of the Bride Part II (1995)                        Comedy
# 4  6                         Heat (1995)         Action|Crime|Thriller

# %%
df
# Out:
#          1                                   Toy Story (1995)  \
# 0        2                                     Jumanji (1995)
# 1        3                            Grumpier Old Men (1995)
# 2        4                           Waiting to Exhale (1995)
# 3        5                 Father of the Bride Part II (1995)
# 4        6                                        Heat (1995)
# 5        7                                     Sabrina (1995)
# 6        8                                Tom and Huck (1995)
# 7        9                                Sudden Death (1995)
# 8       10                                   GoldenEye (1995)
# 9       11                     American President, The (1995)
# 10      12                 Dracula: Dead and Loving It (1995)
# 11      13                                       Balto (1995)
# 12      14                                       Nixon (1995)
# 13      15                            Cutthroat Island (1995)
# ...

# %%
import pandas as pd
rating = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ratings.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-12-917ab42bea92> in <module>()
#       1 import pandas as pd
# ----> 2 rating = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ratings.dat', delimiter = '::')
#
# ...

# %%
import pandas as pd
ratings = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ratings.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
import pandas as pd
ratings = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ratings.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-14-9b2ac9cf3855> in <module>()
#       1 import pandas as pd
# ----> 2 ratings = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ratings.dat', delimiter = '::')
#       3
#
# ...

# %%
import pandas as pd
users = pd.read_csv('C:\mita\Data Science workshop\ml-1m\users.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
users
# Out:
#          1  F  1.1  10  48067
# 0        2  M   56  16  70072
# 1        3  M   25  15  55117
# 2        4  M   45   7  02460
# 3        5  M   25  20  55455
# 4        6  F   50   9  55117
# 5        7  M   35   1  06810
# 6        8  M   25  12  11413
# 7        9  M   25  17  61614
# 8       10  F   35   1  95370
# 9       11  F   25   1  04093
# 10      12  M   25  12  32793
# 11      13  M   45   1  93304
# 12      14  M   35   0  60126
# 13      15  M   25   7  22903
# 14      16  F   35   0  20670
# 15      17  M   50   1  95350
# 16      18  F   18   3  95825
# 17      19  M    1  10  48073
# 18      20  M   25  14  55113
# 19      21  M   18  16  99353
# 20      22  M   18  15  53706
# 21      23  M   35   0  90049
# 22      24  F   25   7  10023
# 23      25  M   18   4  01609
# 24      26  M   25   7  23112
# 25      27  M   25  11  19130
# 26      28  F   25   1  14607
# 27      29  M   35   7  33407
# 28      30  F   35   7  19143
# 29      31  M   56   7  06840
# ...

# %%
import pandas as pd
ratings = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ratings.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-17-7a4c585fb4f1> in <module>()
#       1 import pandas as pd
# ----> 2 ratings = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ratings.dat', delimiter = '::')
#
# ...

# %%
import pandas as pd
users = pd.read_csv('C:\mita\Data Science workshop\ml-1m\users.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
users
# Out:
#          1  F  1.1  10  48067
# 0        2  M   56  16  70072
# 1        3  M   25  15  55117
# 2        4  M   45   7  02460
# 3        5  M   25  20  55455
# 4        6  F   50   9  55117
# 5        7  M   35   1  06810
# 6        8  M   25  12  11413
# 7        9  M   25  17  61614
# 8       10  F   35   1  95370
# 9       11  F   25   1  04093
# 10      12  M   25  12  32793
# 11      13  M   45   1  93304
# 12      14  M   35   0  60126
# 13      15  M   25   7  22903
# 14      16  F   35   0  20670
# 15      17  M   50   1  95350
# 16      18  F   18   3  95825
# 17      19  M    1  10  48073
# 18      20  M   25  14  55113
# 19      21  M   18  16  99353
# 20      22  M   18  15  53706
# 21      23  M   35   0  90049
# 22      24  F   25   7  10023
# 23      25  M   18   4  01609
# 24      26  M   25   7  23112
# 25      27  M   25  11  19130
# 26      28  F   25   1  14607
# 27      29  M   35   7  33407
# 28      30  F   35   7  19143
# 29      31  M   56   7  06840
# ...

# %%
import pandas as pd
ratings = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ratings.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-20-7a4c585fb4f1> in <module>()
#       1 import pandas as pd
# ----> 2 ratings = pd.read_csv('C:\mita\Data Science workshop\ml-1m\ratings.dat', delimiter = '::')
#
# ...

# %%
import pandas as pd
ratings = pd.read_csv('ratings.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
ratings
# Out:
#             1  1193  5  978300760
# 0           1   661  3  978302109
# 1           1   914  3  978301968
# 2           1  3408  4  978300275
# 3           1  2355  5  978824291
# 4           1  1197  3  978302268
# 5           1  1287  5  978302039
# 6           1  2804  5  978300719
# 7           1   594  4  978302268
# 8           1   919  4  978301368
# 9           1   595  5  978824268
# 10          1   938  4  978301752
# 11          1  2398  4  978302281
# 12          1  2918  4  978302124
# 13          1  1035  5  978301753
# 14          1  2791  4  978302188
# 15          1  2687  3  978824268
# 16          1  2018  4  978301777
# 17          1  3105  5  978301713
# 18          1  2797  4  978302039
# 19          1  2321  3  978302205
# 20          1   720  3  978300760
# 21          1  1270  5  978300055
# 22          1   527  5  978824195
# 23          1  2340  3  978300103
# 24          1    48  5  978824351
# 25          1  1097  4  978301953
# ...

# %%
combined = pd.merge('movies','ratings')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-53fd935b555b> in <module>()
# ----> 1 combined = pd.merge('movies','ratings')
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\tools\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy, indicator=indicator)
#      39     return op.get_result()
#      40 if __debug__:
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\tools\merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     192             raise ValueError(
# ...

# %%
combined = pd.merge('movies',pd.merge('users','ratings'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-ae393a4989b1> in <module>()
# ----> 1 combined = pd.merge(movies,pd.merge(users,ratings))
#
# NameError: name 'movies' is not defined

# %%
combined = pd.merge('movies',pd.merge('users','ratings'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-53fd935b555b> in <module>()
# ----> 1 combined = pd.merge('movies','ratings')
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\tools\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy, indicator=indicator)
#      39     return op.get_result()
#      40 if __debug__:
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\tools\merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     192             raise ValueError(
# ...

# %%
combined = pd.merge('movies',pd.merge('users','ratings'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-03182d53efb0> in <module>()
# ----> 1 combined = pd.merge('movies',pd.merge('users','ratings'))
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\tools\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy, indicator=indicator)
#      39     return op.get_result()
#      40 if __debug__:
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\tools\merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     192             raise ValueError(
# ...

# %%
combined = pd.merge(df,pd.merge(users,ratings))

# %%
combined
# Out:
#            1       Toy Story (1995)   Animation|Children's|Comedy  F  1.1  10  \
# 0          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 1          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 2          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 3          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 4          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 5          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 6          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 7          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 8          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 9          2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# 10         2         Jumanji (1995)  Adventure|Children's|Fantasy  M   56  16
# ...

# %%
import pandas as pd
ratings = pd.read_csv('ratings.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
ratings
# Out:
#          UserID  MovieID  Ratings  TimeStamp
# 0             1     1193        5  978300760
# 1             1      661        3  978302109
# 2             1      914        3  978301968
# 3             1     3408        4  978300275
# 4             1     2355        5  978824291
# 5             1     1197        3  978302268
# 6             1     1287        5  978302039
# 7             1     2804        5  978300719
# 8             1      594        4  978302268
# 9             1      919        4  978301368
# 10            1      595        5  978824268
# 11            1      938        4  978301752
# 12            1     2398        4  978302281
# 13            1     2918        4  978302124
# 14            1     1035        5  978301753
# 15            1     2791        4  978302188
# 16            1     2687        3  978824268
# 17            1     2018        4  978301777
# 18            1     3105        5  978301713
# 19            1     2797        4  978302039
# ...

# %%
import pandas as pd
movies = pd.read_csv('movies.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
import pandas as pd
users = pd.read_csv('users.dat', delimiter = '::')
# Out:
# C:\Users\hp\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
ratings
# Out:
#          UserID  MovieID  Ratings  TimeStamp
# 0             1     1193        5  978300760
# 1             1      661        3  978302109
# 2             1      914        3  978301968
# 3             1     3408        4  978300275
# 4             1     2355        5  978824291
# 5             1     1197        3  978302268
# 6             1     1287        5  978302039
# 7             1     2804        5  978300719
# 8             1      594        4  978302268
# 9             1      919        4  978301368
# 10            1      595        5  978824268
# 11            1      938        4  978301752
# 12            1     2398        4  978302281
# 13            1     2918        4  978302124
# 14            1     1035        5  978301753
# 15            1     2791        4  978302188
# 16            1     2687        3  978824268
# 17            1     2018        4  978301777
# 18            1     3105        5  978301713
# 19            1     2797        4  978302039
# ...

# %%
movies.head()
# Out:
#    MovieID                               Title                         Genre
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
users.head()
# Out:
#    UserID Gender  Age  Occupation Zipcode
# 0       1      F    1          10   48067
# 1       2      M   56          16   70072
# 2       3      M   25          15   55117
# 3       4      M   45           7   02460
# 4       5      M   25          20   55455

# %%
combined = pd.merge(movies,pd.merge(users,ratings))

# %%
combined.head()
# Out:
#    MovieID             Title                        Genre  UserID Gender  Age  \
# 0        1  Toy Story (1995)  Animation|Children's|Comedy       1      F    1
# 1        1  Toy Story (1995)  Animation|Children's|Comedy       6      F   50
# 2        1  Toy Story (1995)  Animation|Children's|Comedy       8      M   25
# 3        1  Toy Story (1995)  Animation|Children's|Comedy       9      M   25
# 4        1  Toy Story (1995)  Animation|Children's|Comedy      10      F   35
#
#    Occupation Zipcode  Ratings  TimeStamp
# 0          10   48067        5  978824268
# 1           9   55117        4  978237008
# 2          12   11413        4  978233496
# 3          17   61614        5  978225952
# 4           1   95370        5  978226474

# %%
combined
# Out:
#          MovieID                  Title                        Genre  UserID  \
# 0              1       Toy Story (1995)  Animation|Children's|Comedy       1
# 1              1       Toy Story (1995)  Animation|Children's|Comedy       6
# 2              1       Toy Story (1995)  Animation|Children's|Comedy       8
# 3              1       Toy Story (1995)  Animation|Children's|Comedy       9
# 4              1       Toy Story (1995)  Animation|Children's|Comedy      10
# 5              1       Toy Story (1995)  Animation|Children's|Comedy      18
# 6              1       Toy Story (1995)  Animation|Children's|Comedy      19
# 7              1       Toy Story (1995)  Animation|Children's|Comedy      21
# 8              1       Toy Story (1995)  Animation|Children's|Comedy      23
# 9              1       Toy Story (1995)  Animation|Children's|Comedy      26
# 10             1       Toy Story (1995)  Animation|Children's|Comedy      28
# ...

# %%
combined.sort_values(by=['Genre','Ratings'], ascending=[False, True], inplace=True)

combined
# Out:
#         MovieID                                Title    Genre  UserID Gender  \
# 56694       210                     Wild Bill (1995)  Western     461      M
# 56697       210                     Wild Bill (1995)  Western     720      M
# 56710       210                     Wild Bill (1995)  Western    2744      M
# 110727      383                    Wyatt Earp (1994)  Western     136      M
# 110749      383                    Wyatt Earp (1994)  Western     720      M
# 110750      383                    Wyatt Earp (1994)  Western     752      F
# 110775      383                    Wyatt Earp (1994)  Western    1333      M
# 110847      383                    Wyatt Earp (1994)  Western    3205      F
# 110867      383                    Wyatt Earp (1994)  Western    3500      M
# 110897      383                    Wyatt Earp (1994)  Western    4021      M
# 110900      383                    Wyatt Earp (1994)  Western    4049      M
# ...

# %%
combined.sort_values(by=['Genre','Ratings'], ascending=[False, False], inplace=True)

combined
# Out:
#         MovieID                                Title    Genre  UserID Gender  \
# 56698       210                     Wild Bill (1995)  Western     948      M
# 56702       210                     Wild Bill (1995)  Western    1224      M
# 56719       210                     Wild Bill (1995)  Western    3949      M
# 110742      383                    Wyatt Earp (1994)  Western     452      M
# 110746      383                    Wyatt Earp (1994)  Western     543      M
# 110798      383                    Wyatt Earp (1994)  Western    1920      F
# 110841      383                    Wyatt Earp (1994)  Western    3032      M
# 110862      383                    Wyatt Earp (1994)  Western    3435      M
# 110865      383                    Wyatt Earp (1994)  Western    3476      M
# 110877      383                    Wyatt Earp (1994)  Western    3716      M
# 110884      383                    Wyatt Earp (1994)  Western    3823      M
# ...

# %%
combined = pd.merge(movies,pd.merge(users,ratings))

# %%
combined
# Out:
#          MovieID                  Title                        Genre  UserID  \
# 0              1       Toy Story (1995)  Animation|Children's|Comedy       1
# 1              1       Toy Story (1995)  Animation|Children's|Comedy       6
# 2              1       Toy Story (1995)  Animation|Children's|Comedy       8
# 3              1       Toy Story (1995)  Animation|Children's|Comedy       9
# 4              1       Toy Story (1995)  Animation|Children's|Comedy      10
# 5              1       Toy Story (1995)  Animation|Children's|Comedy      18
# 6              1       Toy Story (1995)  Animation|Children's|Comedy      19
# 7              1       Toy Story (1995)  Animation|Children's|Comedy      21
# 8              1       Toy Story (1995)  Animation|Children's|Comedy      23
# 9              1       Toy Story (1995)  Animation|Children's|Comedy      26
# 10             1       Toy Story (1995)  Animation|Children's|Comedy      28
# ...

# %%
combined.head(10)
# Out:
#    MovieID             Title                        Genre  UserID Gender  Age  \
# 0        1  Toy Story (1995)  Animation|Children's|Comedy       1      F    1
# 1        1  Toy Story (1995)  Animation|Children's|Comedy       6      F   50
# 2        1  Toy Story (1995)  Animation|Children's|Comedy       8      M   25
# 3        1  Toy Story (1995)  Animation|Children's|Comedy       9      M   25
# 4        1  Toy Story (1995)  Animation|Children's|Comedy      10      F   35
# 5        1  Toy Story (1995)  Animation|Children's|Comedy      18      F   18
# 6        1  Toy Story (1995)  Animation|Children's|Comedy      19      M    1
# 7        1  Toy Story (1995)  Animation|Children's|Comedy      21      M   18
# 8        1  Toy Story (1995)  Animation|Children's|Comedy      23      M   35
# 9        1  Toy Story (1995)  Animation|Children's|Comedy      26      M   25
#
#    Occupation Zipcode  Ratings  TimeStamp
# 0          10   48067        5  978824268
# ...

# %%
cobbined.head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-645a8a7c3d54> in <module>()
# ----> 1 cobbined.head(15)
#
# NameError: name 'cobbined' is not defined

# %%
combined.head(15)
# Out:
#     MovieID             Title                        Genre  UserID Gender  \
# 0         1  Toy Story (1995)  Animation|Children's|Comedy       1      F
# 1         1  Toy Story (1995)  Animation|Children's|Comedy       6      F
# 2         1  Toy Story (1995)  Animation|Children's|Comedy       8      M
# 3         1  Toy Story (1995)  Animation|Children's|Comedy       9      M
# 4         1  Toy Story (1995)  Animation|Children's|Comedy      10      F
# 5         1  Toy Story (1995)  Animation|Children's|Comedy      18      F
# 6         1  Toy Story (1995)  Animation|Children's|Comedy      19      M
# 7         1  Toy Story (1995)  Animation|Children's|Comedy      21      M
# 8         1  Toy Story (1995)  Animation|Children's|Comedy      23      M
# 9         1  Toy Story (1995)  Animation|Children's|Comedy      26      M
# 10        1  Toy Story (1995)  Animation|Children's|Comedy      28      F
# 11        1  Toy Story (1995)  Animation|Children's|Comedy      34      F
# ...

# %%
combined
# Out:
#          MovieID                  Title                        Genre  UserID  \
# 0              1       Toy Story (1995)  Animation|Children's|Comedy       1
# 1              1       Toy Story (1995)  Animation|Children's|Comedy       6
# 2              1       Toy Story (1995)  Animation|Children's|Comedy       8
# 3              1       Toy Story (1995)  Animation|Children's|Comedy       9
# 4              1       Toy Story (1995)  Animation|Children's|Comedy      10
# 5              1       Toy Story (1995)  Animation|Children's|Comedy      18
# 6              1       Toy Story (1995)  Animation|Children's|Comedy      19
# 7              1       Toy Story (1995)  Animation|Children's|Comedy      21
# 8              1       Toy Story (1995)  Animation|Children's|Comedy      23
# 9              1       Toy Story (1995)  Animation|Children's|Comedy      26
# 10             1       Toy Story (1995)  Animation|Children's|Comedy      28
# ...

# %%
combined.sort_values(by=['Genre','Ratings'], ascending=[False, False], inplace=True)

combined
# Out:
#         MovieID                                Title    Genre  UserID Gender  \
# 56698       210                     Wild Bill (1995)  Western     948      M
# 56702       210                     Wild Bill (1995)  Western    1224      M
# 56719       210                     Wild Bill (1995)  Western    3949      M
# 110742      383                    Wyatt Earp (1994)  Western     452      M
# 110746      383                    Wyatt Earp (1994)  Western     543      M
# 110798      383                    Wyatt Earp (1994)  Western    1920      F
# 110841      383                    Wyatt Earp (1994)  Western    3032      M
# 110862      383                    Wyatt Earp (1994)  Western    3435      M
# 110865      383                    Wyatt Earp (1994)  Western    3476      M
# 110877      383                    Wyatt Earp (1994)  Western    3716      M
# 110884      383                    Wyatt Earp (1994)  Western    3823      M
# ...

# %%
combined.head(10)
# Out:
#         MovieID              Title    Genre  UserID Gender  Age  Occupation  \
# 56698       210   Wild Bill (1995)  Western     948      M   56          12
# 56702       210   Wild Bill (1995)  Western    1224      M   50          13
# 56719       210   Wild Bill (1995)  Western    3949      M   45           0
# 110742      383  Wyatt Earp (1994)  Western     452      M   50          17
# 110746      383  Wyatt Earp (1994)  Western     543      M   25           5
# 110798      383  Wyatt Earp (1994)  Western    1920      F   35           7
# 110841      383  Wyatt Earp (1994)  Western    3032      M   25           0
# 110862      383  Wyatt Earp (1994)  Western    3435      M   45           1
# 110865      383  Wyatt Earp (1994)  Western    3476      M   50           0
# 110877      383  Wyatt Earp (1994)  Western    3716      M   18          12
#
#        Zipcode  Ratings  TimeStamp
# 56698    43056        5  975228815
# 56702    02125        5  975249865
# ...

# %%
movie_ratings = pd.merge(movies,pd.merge(users,ratings))
movie_ratings
# Out:
#          MovieID                  Title                        Genre  UserID  \
# 0              1       Toy Story (1995)  Animation|Children's|Comedy       1
# 1              1       Toy Story (1995)  Animation|Children's|Comedy       6
# 2              1       Toy Story (1995)  Animation|Children's|Comedy       8
# 3              1       Toy Story (1995)  Animation|Children's|Comedy       9
# 4              1       Toy Story (1995)  Animation|Children's|Comedy      10
# 5              1       Toy Story (1995)  Animation|Children's|Comedy      18
# 6              1       Toy Story (1995)  Animation|Children's|Comedy      19
# 7              1       Toy Story (1995)  Animation|Children's|Comedy      21
# 8              1       Toy Story (1995)  Animation|Children's|Comedy      23
# 9              1       Toy Story (1995)  Animation|Children's|Comedy      26
# 10             1       Toy Story (1995)  Animation|Children's|Comedy      28
# ...

# %%
most_rated = movie_ratings.groupby('title').size().sort_values(ascending=False)[:25]
most_rated
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-402db8f9a333> in <module>()
# ----> 1 most_rated = movie_ratings.groupby('title').size().sort_values(ascending=False)[:25]
#       2 most_rated
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in groupby(obj, by, **kwds)
#    1425         raise TypeError('invalid type: %s' % type(obj))
#    1426
# -> 1427     return klass(obj, by, **kwds)
#    1428
# ...

# %%
most_rated = movie_ratings.groupby('title').size().sort_values(ascending=False)[:25]
most_rated
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-402db8f9a333> in <module>()
# ----> 1 most_rated = movie_ratings.groupby('title').size().sort_values(ascending=False)[:25]
#       2 most_rated
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in groupby(obj, by, **kwds)
#    1425         raise TypeError('invalid type: %s' % type(obj))
#    1426
# -> 1427     return klass(obj, by, **kwds)
#    1428
# ...

# %%
most_rated = movie_ratings.groupby('Title').size().sort_values(ascending=False)[:25]
most_rated
# Out:
# Title
# American Beauty (1999)                                   3428
# Star Wars: Episode IV - A New Hope (1977)                2991
# Star Wars: Episode V - The Empire Strikes Back (1980)    2990
# Star Wars: Episode VI - Return of the Jedi (1983)        2883
# Jurassic Park (1993)                                     2672
# Saving Private Ryan (1998)                               2653
# Terminator 2: Judgment Day (1991)                        2649
# Matrix, The (1999)                                       2590
# Back to the Future (1985)                                2583
# Silence of the Lambs, The (1991)                         2578
# Men in Black (1997)                                      2538
# Raiders of the Lost Ark (1981)                           2514
# Fargo (1996)                                             2513
# Sixth Sense, The (1999)                                  2459
# Braveheart (1995)                                        2443
# ...

# %%
movie_ratings.Title.value_counts()[:25]
# Out:
# American Beauty (1999)                                   3428
# Star Wars: Episode IV - A New Hope (1977)                2991
# Star Wars: Episode V - The Empire Strikes Back (1980)    2990
# Star Wars: Episode VI - Return of the Jedi (1983)        2883
# Jurassic Park (1993)                                     2672
# Saving Private Ryan (1998)                               2653
# Terminator 2: Judgment Day (1991)                        2649
# Matrix, The (1999)                                       2590
# Back to the Future (1985)                                2583
# Silence of the Lambs, The (1991)                         2578
# Men in Black (1997)                                      2538
# Raiders of the Lost Ark (1981)                           2514
# Fargo (1996)                                             2513
# Sixth Sense, The (1999)                                  2459
# Braveheart (1995)                                        2443
# ...

# %%
movie_stats = movie_ratings.groupby('Title').agg({'rating': [np.size, np.mean]})
movie_stats.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-5849258d03d4> in <module>()
# ----> 1 movie_stats = movie_ratings.groupby('Title').agg({'rating': [np.size, np.mean]})
#       2 movie_stats.head()
#
# NameError: name 'np' is not defined

# %%
import numpy as np
movie_stats = movie_ratings.groupby('Title').agg({'rating': [np.size, np.mean]})
movie_stats.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-bb423ec76f7e> in <module>()
#       1 import numpy as np
# ----> 2 movie_stats = movie_ratings.groupby('Title').agg({'rating': [np.size, np.mean]})
#       3 movie_stats.head()
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3595     @Appender(SelectionMixin._agg_doc)
#    3596     def aggregate(self, arg, *args, **kwargs):
# -> 3597         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3598
#    3599     agg = aggregate
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3112
#    3113         _level = kwargs.pop('_level', None)
# -> 3114         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3115         if how is None:
# ...

# %%
import numpy as np
movie_stats = movie_ratings.groupby('Title').agg({'Ratings': [np.size, np.mean]})
movie_stats.head()
# Out:
#                               Ratings
#                                  size      mean
# Title
# $1,000,000 Duck (1971)             37  3.027027
# 'Night Mother (1986)               70  3.371429
# 'Til There Was You (1997)          52  2.692308
# 'burbs, The (1989)                303  2.910891
# ...And Justice for All (1979)     199  3.713568

# %%
import numpy as np
movie_stats = movie_ratings.groupby('Genre').agg({'Ratings': [np.size, np.mean]})
movie_stats.head
# Out:
#                                               Ratings
#                                                  size      mean
# Genre
# Action                                          12311  3.354886
# Action|Adventure                                10446  3.676814
# Action|Adventure|Animation                        345  4.147826
# Action|Adventure|Animation|Children's|Fantasy     135  2.703704
# Action|Adventure|Animation|Horror|Sci-Fi          618  3.546926

# %%
import numpy as np
movie_stats = movie_ratings.groupby('Genre').agg({'Ratings': [np.size, np.mean]})
movie_stats
# Out:
#                                               Ratings
#                                                  size      mean
# Genre
# Action                                          12311  3.354886
# Action|Adventure                                10446  3.676814
# Action|Adventure|Animation                        345  4.147826
# Action|Adventure|Animation|Children's|Fantasy     135  2.703704
# Action|Adventure|Animation|Horror|Sci-Fi          618  3.546926
# Action|Adventure|Children's                        44  1.318182
# Action|Adventure|Children's|Comedy                518  2.306950
# Action|Adventure|Children's|Fantasy                44  2.090909
# Action|Adventure|Children's|Sci-Fi                350  1.874286
# Action|Adventure|Comedy                          2077  3.095330
# Action|Adventure|Comedy|Crime                    2573  3.137194
# Action|Adventure|Comedy|Horror                    548  3.826642
# Action|Adventure|Comedy|Horror|Sci-Fi             945  3.804233
# ...

# %%
sort_ratings = movie_stats.sort_values(by=['Ratings.mean'], ascending=[False], inplace=True)
sort_ratings
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-99bd390e126b> in <module>()
# ----> 1 sort_ratings = movie_stats.sort_values(by=['Genre','Ratings'], ascending=[False, False], inplace=True)
#       2 sort_ratings
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3137             keys = []
#    3138             for x in by:
# -> 3139                 k = self[x].values
#    3140                 if k.ndim == 2:
#    3141                     raise ValueError('Cannot sort by duplicate column %s' %
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1993             return self._getitem_frame(key)
#    1994         elif is_mi_columns:
# -> 1995             return self._getitem_multilevel(key)
#    1996         else:
# ...

# %%
sort_ratings = movie_stats.sort_values(by=['mean'], ascending=[False], inplace=True)
sort_ratings
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-62da8d819cbb> in <module>()
# ----> 1 sort_ratings = movie_stats.sort_values(by=['Ratings.mean'], ascending=[False], inplace=True)
#       2 sort_ratings
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3149
#    3150             by = by[0]
# -> 3151             k = self[by].values
#    3152             if k.ndim == 2:
#    3153
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1993             return self._getitem_frame(key)
#    1994         elif is_mi_columns:
# -> 1995             return self._getitem_multilevel(key)
#    1996         else:
#    1997             return self._getitem_column(key)
#
# ...

# %%
sort_ratings = movie_stats.sort_values(by=['mean'], ascending=[False], inplace=True)
sort_ratings
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-3746d693f83c> in <module>()
# ----> 1 sort_ratings = movie_stats.sort_values(by=['mean'], ascending=[False], inplace=True)
#       2 sort_ratings
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3149
#    3150             by = by[0]
# -> 3151             k = self[by].values
#    3152             if k.ndim == 2:
#    3153
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1993             return self._getitem_frame(key)
#    1994         elif is_mi_columns:
# -> 1995             return self._getitem_multilevel(key)
#    1996         else:
#    1997             return self._getitem_column(key)
#
# ...

# %%
movie_stats.sort_values([('Ratings', 'mean')], ascending=False).head()
# Out:
#                           Ratings
#                              size      mean
# Genre
# Animation|Comedy|Thriller     688  4.473837
# Sci-Fi|War                   1367  4.449890
# Animation                     459  4.394336
# Film-Noir|Mystery            1584  4.367424
# Adventure|War                1644  4.346107

# %%
movie_stats.sort_values([('Ratings', 'mean')], ascending=False).head(10)
# Out:
#                                   Ratings
#                                      size      mean
# Genre
# Animation|Comedy|Thriller             688  4.473837
# Sci-Fi|War                           1367  4.449890
# Animation                             459  4.394336
# Film-Noir|Mystery                    1584  4.367424
# Adventure|War                        1644  4.346107
# Film-Noir|Romance|Thriller            445  4.294382
# Action|Adventure|Drama|Sci-Fi|War    2990  4.292977
# Film-Noir|Sci-Fi                     1800  4.273333
# Crime|Film-Noir                       867  4.264129
# Film-Noir                             802  4.258105

# %%
users.age.plot.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-897330549008> in <module>()
# ----> 1 users.age.plot.hist(bins=30)
#       2 plt.title("Distribution of users' ages")
#       3 plt.ylabel('count of users')
#       4 plt.xlabel('age');
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
users
# Out:
#       UserID Gender  Age  Occupation Zipcode
# 0          1      F    1          10   48067
# 1          2      M   56          16   70072
# 2          3      M   25          15   55117
# 3          4      M   45           7   02460
# 4          5      M   25          20   55455
# 5          6      F   50           9   55117
# 6          7      M   35           1   06810
# 7          8      M   25          12   11413
# 8          9      M   25          17   61614
# 9         10      F   35           1   95370
# 10        11      F   25           1   04093
# 11        12      M   25          12   32793
# 12        13      M   45           1   93304
# 13        14      M   35           0   60126
# 14        15      M   25           7   22903
# 15        16      F   35           0   20670
# 16        17      M   50           1   95350
# 17        18      F   18           3   95825
# 18        19      M    1          10   48073
# 19        20      M   25          14   55113
# ...

# %%
plt= users.Age.plot.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-3f44df030fec> in <module>()
#       1 users.Age.plot.hist(bins=30)
# ----> 2 plt.title("Distribution of users' ages")
#       3 plt.ylabel('count of users')
#       4 plt.xlabel('age');
#
# NameError: name 'plt' is not defined

# %%
plt= users.Age.plot.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-dec40009eb3b> in <module>()
#       1 plt= users.Age.plot.hist(bins=30)
# ----> 2 plt.title("Distribution of users' ages")
#       3 plt.ylabel('count of users')
#       4 plt.xlabel('age');
#
# TypeError: 'Text' object is not callable

# %%
 users.Age.plot.hist(bins=30)

# %%
plt= users.Age.plot.hist(bins=30)
plt.xlabel('age');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-2c1c689e0301> in <module>()
#       1 plt= users.Age.plot.hist(bins=30)
# ----> 2 plt.title("Distribution of users' ages")
#
# TypeError: 'Text' object is not callable

# %%
plt= users.Age.plot.hist(bins=30)
plt.xlabel('age');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-3765dfb9138e> in <module>()
#       1 plt= users.Age.plot.hist(bins=30)
# ----> 2 plt.xlabel('age');
#
# AttributeError: 'AxesSubplot' object has no attribute 'xlabel'

# %%
import matplotlib.pyplot as plt

# %%
users.Age.plot.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\Users\hp\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc'>

# %%
plt = users.Age.plot.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-f094aeeb4f2f> in <module>()
#       1 plt = users.Age.plot.hist(bins=30)
# ----> 2 plt.title("Distribution of users' ages")
#       3 plt.ylabel('count of users')
#       4 plt.xlabel('age');
#
# TypeError: 'Text' object is not callable

# %%
users.Age.plot.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-cccc88f87a48> in <module>()
#       1 users.Age.plot.hist(bins=30)
# ----> 2 plt.title("Distribution of users' ages")
#       3 plt.ylabel('count of users')
#       4 plt.xlabel('age');
#       5 plt.show()
#
# TypeError: 'Text' object is not callable

# %%
plt

# %%
import matplotlib.pyplot as plt
users.Age.plot.hist(bins=30)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');
plt.show()

# %%
import matplotlib.pyplot as plt
users.Age.plot.hist(bins=20)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');
plt.show()

# %%
labels = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
movie_ratings['age_group'] = pd.cut(movie_ratings.age, range(0, 81, 10), right=False, labels=labels)
movie_ratings[['age', 'age_group']].drop_duplicates()[:10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-05db164ed200> in <module>()
#       1 labels = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
# ----> 2 movie_ratings['age_group'] = pd.cut(movie_ratings.age, range(0, 81, 10), right=False, labels=labels)
#       3 movie_ratings[['age', 'age_group']].drop_duplicates()[:10]
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
movie_ratings
# Out:
#          MovieID                  Title                        Genre  UserID  \
# 0              1       Toy Story (1995)  Animation|Children's|Comedy       1
# 1              1       Toy Story (1995)  Animation|Children's|Comedy       6
# 2              1       Toy Story (1995)  Animation|Children's|Comedy       8
# 3              1       Toy Story (1995)  Animation|Children's|Comedy       9
# 4              1       Toy Story (1995)  Animation|Children's|Comedy      10
# 5              1       Toy Story (1995)  Animation|Children's|Comedy      18
# 6              1       Toy Story (1995)  Animation|Children's|Comedy      19
# 7              1       Toy Story (1995)  Animation|Children's|Comedy      21
# 8              1       Toy Story (1995)  Animation|Children's|Comedy      23
# 9              1       Toy Story (1995)  Animation|Children's|Comedy      26
# 10             1       Toy Story (1995)  Animation|Children's|Comedy      28
# ...

# %%
labels = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
movie_ratings['age_group'] = pd.cut(movie_ratings.Age, range(0, 81, 10), right=False, labels=labels)
movie_ratings[['Age', 'age_group']].drop_duplicates()[:10]
# Out:
#     Age age_group
# 0     1       0-9
# 1    50     50-59
# 2    25     20-29
# 4    35     30-39
# 5    18     10-19
# 14   45     40-49
# 27   56     50-59

# %%
movie_ratings.groupby('age_group').agg({'rating': [np.size, np.mean]})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-6e3c308e537b> in <module>()
# ----> 1 movie_ratings.groupby('age_group').agg({'rating': [np.size, np.mean]})
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3595     @Appender(SelectionMixin._agg_doc)
#    3596     def aggregate(self, arg, *args, **kwargs):
# -> 3597         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3598
#    3599     agg = aggregate
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3112
#    3113         _level = kwargs.pop('_level', None)
# -> 3114         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3115         if how is None:
#    3116             return result
#
# ...

# %%
movie_ratings.groupby('age_group').agg({'Ratings': [np.size, np.mean]})
# Out:
#           Ratings
#              size      mean
# age_group
# 0-9         27211  3.549520
# 10-19      183536  3.507573
# 20-29      395556  3.545235
# 30-39      199003  3.618162
# 40-49       83633  3.638062
# 50-59      111270  3.732677
# 60-69           0       NaN
# 70-79           0       NaN

# %%
most_50 = movie_ratings.groupby('movie_id').size().sort_values(ascending=False)[:50]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-a0bb6aeb7077> in <module>()
# ----> 1 most_50 = movie_ratings.groupby('movie_id').size().sort_values(ascending=False)[:50]
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in groupby(obj, by, **kwds)
#    1425         raise TypeError('invalid type: %s' % type(obj))
#    1426
# -> 1427     return klass(obj, by, **kwds)
#    1428
#    1429
#
# ...

# %%
most_50 = lens.groupby('MovieID').size().sort_values(ascending=False)[:50]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-8edf02d51b64> in <module>()
# ----> 1 most_50 = lens.groupby('MovieID').size().sort_values(ascending=False)[:50]
#
# NameError: name 'lens' is not defined

# %%
most_50 = movie_ratings.groupby('MovieID').size().sort_values(ascending=False)[:50]

# %%
movie_ratings.set_index('MovieID', inplace=True)

# %%
by_age = movie_ratings.loc[most_50.index].groupby(['Title', 'age_group'])
by_age.rating.mean().head(15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-ca7cd97fa937> in <module>()
#       1 by_age = movie_ratings.loc[most_50.index].groupby(['Title', 'age_group'])
# ----> 2 by_age.rating.mean().head(15)
#
# C:\Users\hp\Anaconda2\lib\site-packages\pandas\core\groupby.pyc in __getattr__(self, attr)
#     496
#     497         raise AttributeError("%r object has no attribute %r" %
# --> 498                              (type(self).__name__, attr))
#     499
#     500     plot = property(GroupByPlot)
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'rating'

# %%
by_age = lens.loc[most_50.index].groupby(['title', 'age_group'])
by_age.Ratings.mean().head(15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-2806e214a2a6> in <module>()
# ----> 1 by_age = lens.loc[most_50.index].groupby(['title', 'age_group'])
#       2 by_age.Ratings.mean().head(15)
#
# NameError: name 'lens' is not defined

# %%
by_age = movie_ratings.loc[most_50.index].groupby(['Title', 'age_group'])
by_age.Ratings.mean().head(15)
# Out:
# Title                         age_group
# 2001: A Space Odyssey (1968)  0-9          4.150000
#                               10-19        3.923404
#                               20-29        4.024712
#                               30-39        4.080940
#                               40-49        4.168478
#                               50-59        4.198502
# Abyss, The (1989)             0-9          3.909091
#                               10-19        3.893939
#                               20-29        3.614509
#                               30-39        3.686217
#                               40-49        3.683099
#                               50-59        3.512048
# Airplane! (1980)              0-9          3.794872
#                               10-19        4.076667
#                               20-29        4.002821
# Name: Ratings, dtype: float64

# %%
movie_ratings.head(10)
# Out:
#                     Title                        Genre  UserID Gender  Age  \
# MovieID
# 1        Toy Story (1995)  Animation|Children's|Comedy       1      F    1
# 1        Toy Story (1995)  Animation|Children's|Comedy       6      F   50
# 1        Toy Story (1995)  Animation|Children's|Comedy       8      M   25
# 1        Toy Story (1995)  Animation|Children's|Comedy       9      M   25
# 1        Toy Story (1995)  Animation|Children's|Comedy      10      F   35
# 1        Toy Story (1995)  Animation|Children's|Comedy      18      F   18
# 1        Toy Story (1995)  Animation|Children's|Comedy      19      M    1
# 1        Toy Story (1995)  Animation|Children's|Comedy      21      M   18
# 1        Toy Story (1995)  Animation|Children's|Comedy      23      M   35
# 1        Toy Story (1995)  Animation|Children's|Comedy      26      M   25
#
#          Occupation Zipcode  Ratings  TimeStamp age_group
# MovieID
# 1                10   48067        5  978824268       0-9
# ...

# %%
by_age = movie_ratings.loc[most_50.index].groupby(['Title', 'Gender', 'age_group'])
by_age.Ratings.mean().head(15)
# Out:
# Title                         Gender  age_group
# 2001: A Space Odyssey (1968)  F       0-9          3.700000
#                                       10-19        3.473684
#                                       20-29        3.770000
#                                       30-39        3.924051
#                                       40-49        3.918367
#                                       50-59        3.941176
#                               M       0-9          4.300000
#                                       10-19        4.010152
#                                       20-29        4.074951
#                                       30-39        4.121711
#                                       40-49        4.259259
#                                       50-59        4.286432
# Abyss, The (1989)             F       0-9          3.833333
#                                       10-19        3.796610
#                                       20-29        3.578512
# ...

# %%
by_age = movie_ratings.loc[most_50.index].groupby(['Title', 'Gender', 'age_group'])
by_age.Ratings.mean().head(25)
# Out:
# Title                         Gender  age_group
# 2001: A Space Odyssey (1968)  F       0-9          3.700000
#                                       10-19        3.473684
#                                       20-29        3.770000
#                                       30-39        3.924051
#                                       40-49        3.918367
#                                       50-59        3.941176
#                               M       0-9          4.300000
#                                       10-19        4.010152
#                                       20-29        4.074951
#                                       30-39        4.121711
#                                       40-49        4.259259
#                                       50-59        4.286432
# Abyss, The (1989)             F       0-9          3.833333
#                                       10-19        3.796610
#                                       20-29        3.578512
# ...
